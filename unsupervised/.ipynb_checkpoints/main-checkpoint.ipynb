# %%
import torch
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
from autoencoder import AE
from dataloader import dataloader

##### DATA LOADER ####
DL = dataloader()
A = DL.load_anomaly()
N = DL.load_normal() 
DL.show_data(A)
DL.show_data(N)
# Out:
# Loading anomalies
# Preproccessing
# Loading normals
# Preproccessing
# Nr of data points:  587
# Nr of data points:  610

# %%
#### RESNET ####

# %%
#### ENCODER ####

# %%
#### DECODER ####

# %%
#### CLASSIFY ####
